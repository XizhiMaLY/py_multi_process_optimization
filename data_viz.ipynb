# %%
import matplotlib.pyplot as plt
import numpy as np


# labels = ['G1', 'G2', 'G3', 'G4', 'G5']
labels = ['50MB', '300MB', '2.5GB', '16GB']
men_means = [20, 34, 30, 35, 27]
single_module = [5.6, 38.1, 688, 2218]
multi_module = [1.8, 11.8, 91.2, 760.2]
multi_module_unoptimized = [1.8, 8.6, 92.2, 851]

women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.80  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/3, single_module, width/3, label='single_module', color='firebrick')
rects2 = ax.bar(x, multi_module, width/3, label='multi_module', color='steelblue')
rects3 = ax.bar(x + width/3, multi_module_unoptimized, width/3, label='multi_module_unoptimized',color='seagreen')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Process Time (seconds)')
ax.set_title('Process Time by File Size and Solver')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)

fig.tight_layout()

plt.savefig('Process Time by File Size and Solver.png')
